# %%
git init

# %% [markdown]
# ***kiểm tra cấu hình hiện tại bằng git config -l***

# %%
git config -l

# %% [markdown]
# Add file

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# commit code

# %% [markdown]
# Nếu bạn thay đổi file hãy check git status

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Trường hợp này chúng ta git add rồi check status lần nửa**

# %% [markdown]
# ![image.png](attachment:image.png)
